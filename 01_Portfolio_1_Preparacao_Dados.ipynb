# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriel-data/Colab_Project_Data_Analytics/blob/main/01_Portfolio_1_Preparacao_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OBJETIVO
#
# ## 1. Analisar a estrutura de um Dataset de Produtos (Estoque + Preço + Marca + Categoria).
#
# ## 2. Tratar tipos de campos
#
# ## 3. Tratar valores Nulos e vazios.
#
# ## 4. Gerar novo Dataset tratado.

# %% [markdown]
# # Preparação do ambiente.

# %%
# Importar as bibliotecas
import numpy as np
import pandas as pd

# %%
### Montar o Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Preparação, organização e estruturação dos dados.

# %% [markdown]
# ### Extração dos Dados

# %%
# CARREGAR O DATASET em formato Excel, tipo de arquivo .XLSX.

# O arquivo na origem possui mais de uma planilha, por isso foi acrescentado um direcionamento para a Lista1.

dados = pd.read_excel('/content/drive/MyDrive/PYT/1_Portfolio/0_Estudo_Plan_Produtos/Produtos1.xlsx', sheet_name='Lista1')

# %% [markdown]
# ### Apresentação do DATASET: Produtos 1
#
# Produto (SKU), Título, Marca, Categoria, Valor de Custo, Preço de Venda, Estoques, Armazém, Filial e Tabela.

# %%
# Primeiros 10 registros

dados.head(11)
# Out:
#           SKU   TITULO       MARCA   CATEGORIA  VALOR_CUSTO  PRECO_VISTA  \
# 0   XYZ102030   Item 1      Amazon  Eletronico        300.0        450.0
# 1   XYZ102031   Item 2       Apple         NaN        650.0        975.0
# 2   XYZ102032   Item 3      Google    Internet        900.0       1350.0
# 3   XYZ102033   Item 4   Microsoft    Software       6500.0       9750.0
# 4   XYZ102034   Item 5         NaN  Eletronico        650.0        975.0
# 5   XYZ102035   Item 6  Mastercard     Serviço        650.0        975.0
# 6   XYZ102036   Item 7      Google    Internet        990.0       1485.0
# 7   XYZ102037   Item 8   Microsoft    Software        650.0        975.0
# 8   XYZ102038   Item 9        Dove      Beleza        300.0        450.0
# 9   ABC102039  Item 10        Dove      Beleza        300.0        450.0
# 10  ABC102040  Item 11  Mastercard     Serviço        650.0        975.0
#
#     PRECO_PRAZO  ESTOQUE  TOTAL_VLR_CUSTO  TOTAL_VLR_VENDA  Armazem  FILIAL  \
# ...

# %% [markdown]
# ##### Estrutura do DATASET

# %%
# O número total de linhas é 20 e o número total de colunas é 12.

# Resultado: afirmativo. De acordo com a validação do arquivo XLSX que foi realizado antecipadamente a carga.

dados.shape
# Out:
# (22, 13)

# %% [markdown]
# ## 2. Tratar tipos de campos

# %%
# 1. Ajustes de atributos/campos (colunas) do dataset.

# object: strings
# int64: inteiros
# float64: reais
# complex: complexos

# Resultado: Negativo. Observa-se que o atributo "FILIAL" precisa ser transformado para String.

dados.dtypes
# Out:
# SKU                 object
# TITULO              object
# MARCA               object
# CATEGORIA           object
# VALOR_CUSTO        float64
# PRECO_VISTA        float64
# PRECO_PRAZO        float64
# ESTOQUE            float64
# TOTAL_VLR_CUSTO    float64
# TOTAL_VLR_VENDA    float64
# Armazem            float64
# FILIAL             float64
# TABELA              object
# dtype: object

# %% [markdown]
# ##### 1. Ajustes de atributos/campos (colunas) do dataset. Transformação:

# %%
# Com a biblioteca Pandas carregada antecipadamente, realizei a ação abaixo:

# Convertendo para int64
dados['FILIAL'] = dados['FILIAL'].astype('object')

# Após a conversão
print(dados.dtypes)

# Resultado: Positivo. O campo "FILIAL" passou ao tipo Object = string.
# Out:
# SKU                 object
# TITULO              object
# MARCA               object
# CATEGORIA           object
# VALOR_CUSTO        float64
# PRECO_VISTA        float64
# PRECO_PRAZO        float64
# ESTOQUE            float64
# TOTAL_VLR_CUSTO    float64
# TOTAL_VLR_VENDA    float64
# Armazem            float64
# FILIAL              object
# TABELA              object
# dtype: object

# %% [markdown]
# ## 3. Tratar valores Nulos e vazios.

# %%
################ Opção [1]: Verifique se há valores em branco em todas as colunas
#valores_em_branco = dados.isnull()

#print(valores_em_branco)

################ Opção [2]: Verifique se há valores em branco em pelo menos uma coluna

#linhas_com_branco = valores_em_branco.any(axis=1)

#print(linhas_com_branco)


#### Opção [3]: Se você quiser ver as linhas com valores em branco
linhas_com_valores_em_branco = dados[linhas_com_branco]

print(linhas_com_valores_em_branco)
# Out:
#           SKU  TITULO  MARCA   CATEGORIA  VALOR_CUSTO  PRECO_VISTA  \
# 1   XYZ102031  Item 2  Apple         NaN        650.0        975.0
# 4   XYZ102034  Item 5    NaN  Eletronico        650.0        975.0
# 20     102030     NaN    NaN         NaN          NaN          NaN
# 21     506080     NaN    NaN         NaN          NaN          NaN
#
#     PRECO_PRAZO  ESTOQUE  TOTAL_VLR_CUSTO  TOTAL_VLR_VENDA  Armazem FILIAL  \
# 1        1072.5     20.0          13000.0          19500.0      1.0   18.0
# 4        1072.5     50.0          32500.0          48750.0      3.0   18.0
# 20          NaN      NaN              NaN              NaN      NaN    NaN
# 21          NaN      NaN              NaN              NaN      NaN    NaN
#
#    TABELA
# 1      RS
# 4      RS
# 20    NaN
# 21    NaN

# %%
##### [1] ###### Preenchimento de registros em branco p/ Coluna: aplica-se a todas as linhas vazias.

#dados['MARCA'] = dados['MARCA'].fillna('Amazon')

##### [2] ###### Preenchimento de registros em branco p/ Coluna/linha ESPECÍFICA
dados.at[1, 'CATEGORIA'] = 'Eletronico'

dados.head()
# Out:
#          SKU  TITULO      MARCA   CATEGORIA  VALOR_CUSTO  PRECO_VISTA  \
# 0  XYZ102030  Item 1     Amazon  Eletronico        300.0        450.0
# 1  XYZ102031  Item 2      Apple  Eletronico        650.0        975.0
# 2  XYZ102032  Item 3     Google    Internet        900.0       1350.0
# 3  XYZ102033  Item 4  Microsoft    Software       6500.0       9750.0
# 4  XYZ102034  Item 5     Amazon  Eletronico        650.0        975.0
#
#    PRECO_PRAZO  ESTOQUE  TOTAL_VLR_CUSTO  TOTAL_VLR_VENDA  Armazem FILIAL  \
# 0        495.0     10.0           3000.0           4500.0      1.0   18.0
# 1       1072.5     20.0          13000.0          19500.0      1.0   18.0
# 2       1485.0     30.0          27000.0          40500.0      2.0   17.0
# 3      10725.0     10.0          65000.0          97500.0      1.0    2.0
# 4       1072.5     50.0          32500.0          48750.0      3.0   18.0
#
#   TABELA   categoria
# 0     RS         NaN
# 1     RS  Eletronico
# 2     SP         NaN
# ...

# %%
# REVISÃO 1: restam registros das linhas 20 e 21 em branco. Verificado que estas duas linhas podem ser removidas.

#### Opção [3]: Se você quiser ver as linhas com valores em branco
linhas_com_valores_em_branco = dados[linhas_com_branco]

print(linhas_com_valores_em_branco)
# Out:
#           SKU  TITULO   MARCA   CATEGORIA  VALOR_CUSTO  PRECO_VISTA  \
# 1   XYZ102031  Item 2   Apple  Eletronico        650.0        975.0
# 4   XYZ102034  Item 5  Amazon  Eletronico        650.0        975.0
# 20     102030     NaN  Amazon         NaN          NaN          NaN
# 21     506080     NaN  Amazon         NaN          NaN          NaN
#
#     PRECO_PRAZO  ESTOQUE  TOTAL_VLR_CUSTO  TOTAL_VLR_VENDA  Armazem FILIAL  \
# 1        1072.5     20.0          13000.0          19500.0      1.0   18.0
# 4        1072.5     50.0          32500.0          48750.0      3.0   18.0
# 20          NaN      NaN              NaN              NaN      NaN    NaN
# 21          NaN      NaN              NaN              NaN      NaN    NaN
#
#    TABELA   categoria
# 1      RS  Eletronico
# 4      RS         NaN
# 20    NaN         NaN
# 21    NaN         NaN

# %%
# Remoção de linhas

dados = dados.drop([20, 21])

dados.head()
# Out:
#          SKU  TITULO      MARCA   CATEGORIA  VALOR_CUSTO  PRECO_VISTA  \
# 0  XYZ102030  Item 1     Amazon  Eletronico        300.0        450.0
# 1  XYZ102031  Item 2      Apple  Eletronico        650.0        975.0
# 2  XYZ102032  Item 3     Google    Internet        900.0       1350.0
# 3  XYZ102033  Item 4  Microsoft    Software       6500.0       9750.0
# 4  XYZ102034  Item 5     Amazon  Eletronico        650.0        975.0
#
#    PRECO_PRAZO  ESTOQUE  TOTAL_VLR_CUSTO  TOTAL_VLR_VENDA  Armazem FILIAL  \
# 0        495.0     10.0           3000.0           4500.0      1.0   18.0
# 1       1072.5     20.0          13000.0          19500.0      1.0   18.0
# 2       1485.0     30.0          27000.0          40500.0      2.0   17.0
# 3      10725.0     10.0          65000.0          97500.0      1.0    2.0
# 4       1072.5     50.0          32500.0          48750.0      3.0   18.0
#
#   TABELA   categoria
# 0     RS         NaN
# 1     RS  Eletronico
# 2     SP         NaN
# ...

# %%
# REVISÃO 2: resta uma linha com valor em branco que está relacionada em uma coluna desnecessária "categoria".

#### Opção [3]: Se você quiser ver as linhas com valores em branco
linhas_com_valores_em_branco = dados[linhas_com_branco]

print(linhas_com_valores_em_branco)
# Out:
#          SKU  TITULO   MARCA   CATEGORIA  VALOR_CUSTO  PRECO_VISTA  \
# 1  XYZ102031  Item 2   Apple  Eletronico        650.0        975.0
# 4  XYZ102034  Item 5  Amazon  Eletronico        650.0        975.0
#
#    PRECO_PRAZO  ESTOQUE  TOTAL_VLR_CUSTO  TOTAL_VLR_VENDA  Armazem FILIAL  \
# 1       1072.5     20.0          13000.0          19500.0      1.0   18.0
# 4       1072.5     50.0          32500.0          48750.0      3.0   18.0
#
#   TABELA   categoria
# 1     RS  Eletronico
# 4     RS         NaN
# <ipython-input-26-e7eb556c6b43>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   linhas_com_valores_em_branco = dados[linhas_com_branco]

# %%
# Remoçao de campos (colunas) desnecessárias:

dados = dados.drop(columns=['categoria', 'Armazem'])

# %%
# Revisão 4: Constatado que não existem mais linhas com registros em branco.

################ Opção [1]: Verifique se há valores em branco em todas as colunas
#valores_em_branco = dados.isnull()

#print(valores_em_branco)

################ Opção [2]: Verifique se há valores em branco em pelo menos uma coluna

#linhas_com_branco = valores_em_branco.any(axis=1)

#print(linhas_com_branco)


#### Opção [3]: Se você quiser ver as linhas com valores em branco
linhas_com_valores_em_branco = dados[linhas_com_branco]

print(linhas_com_valores_em_branco)
# Out:
# Empty DataFrame
# Columns: [SKU, TITULO, MARCA, CATEGORIA, VALOR_CUSTO, PRECO_VISTA, PRECO_PRAZO, ESTOQUE, TOTAL_VLR_CUSTO, TOTAL_VLR_VENDA, FILIAL, TABELA]
# Index: []

# %%
dados.head()
# Out:
#          SKU  TITULO      MARCA   CATEGORIA  VALOR_CUSTO  PRECO_VISTA  \
# 0  XYZ102030  Item 1     Amazon  Eletronico        300.0        450.0
# 1  XYZ102031  Item 2      Apple  Eletronico        650.0        975.0
# 2  XYZ102032  Item 3     Google    Internet        900.0       1350.0
# 3  XYZ102033  Item 4  Microsoft    Software       6500.0       9750.0
# 4  XYZ102034  Item 5     Amazon  Eletronico        650.0        975.0
#
#    PRECO_PRAZO  ESTOQUE  TOTAL_VLR_CUSTO  TOTAL_VLR_VENDA FILIAL TABELA
# 0        495.0     10.0           3000.0           4500.0   18.0     RS
# 1       1072.5     20.0          13000.0          19500.0   18.0     RS
# 2       1485.0     30.0          27000.0          40500.0   17.0     SP
# 3      10725.0     10.0          65000.0          97500.0    2.0     DF
# 4       1072.5     50.0          32500.0          48750.0   18.0     RS

# %%
# @title CATEGORIA

from matplotlib import pyplot as plt
import seaborn as sns
dados.groupby('CATEGORIA').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## 4. Gerar novo Dataset tratado.

# %%
# Copiando o dataset original para tabalhar no próximo Dataset

dados2 = dados.copy()  # Faz uma cópia do DataFrame original

dados2.head(10)
# Out:
#          SKU   TITULO       MARCA   CATEGORIA  VALOR_CUSTO  PRECO_VISTA  \
# 0  XYZ102030   Item 1      Amazon  Eletronico        300.0        450.0
# 1  XYZ102031   Item 2       Apple  Eletronico        650.0        975.0
# 2  XYZ102032   Item 3      Google    Internet        900.0       1350.0
# 3  XYZ102033   Item 4   Microsoft    Software       6500.0       9750.0
# 4  XYZ102034   Item 5      Amazon  Eletronico        650.0        975.0
# 5  XYZ102035   Item 6  Mastercard     Serviço        650.0        975.0
# 6  XYZ102036   Item 7      Google    Internet        990.0       1485.0
# 7  XYZ102037   Item 8   Microsoft    Software        650.0        975.0
# 8  XYZ102038   Item 9        Dove      Beleza        300.0        450.0
# 9  ABC102039  Item 10        Dove      Beleza        300.0        450.0
#
#    PRECO_PRAZO  ESTOQUE  TOTAL_VLR_CUSTO  TOTAL_VLR_VENDA FILIAL TABELA
# 0        495.0     10.0           3000.0           4500.0   18.0     RS
# ...

# %%
# Gerando arquivo em formato XLSX, Excel:

dados2.to_excel('/content/drive/MyDrive/PYT/1_Portfolio/0_Estudo_Plan_Produtos/Prod1-Tratado-EX.xlsx', index=False)

# %%
# Gerando arquivo em formato CSV:

dados2.to_csv('/content/drive/MyDrive/PYT/1_Portfolio/0_Estudo_Plan_Produtos/Prod1-Tra-CSV.CSV', index=False)

# %% [markdown]
# ### Próxima etapa:
#
# ### Iclusão de campos matemáticos com Margem de Lucro por preço à vista e preço a prazo.
